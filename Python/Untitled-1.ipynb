# %% [markdown]
# NAMA: TITIK NUR LATIFAH
# NRP: 1152700001
# KELAS: IF-A

# %% [markdown]
# django.shortcuts.render()
#
# Fungsi ini digunakan untuk merender sebuah template dan mengembalikan HttpResponse dengan konten yang dirender.

# %%
from django.shortcuts import render

def my_view(request):
    context = {
        'key': 'value',
        'another_key': 'another_value',
    }
    return render(request, 'template_name.html', context)

# %% [markdown]
# django.http.HttpResponse()
#
# Fungsi ini digunakan untuk mengembalikan respon HTTP dengan konten yang diberikan.

# %%
from django.http import HttpResponse

def my_view(request):
    return HttpResponse("Hello, world!")

# %% [markdown]
# django.urls.path()
#
# Fungsi ini digunakan untuk mendefinisikan URL pattern dalam aplikasi Django.

# %%
from django.urls import path
from . import views

urlpatterns = [
    path('', views.index, name='index'),
]

# %% [markdown]
# django.db.models.Model
#
# Fungsi ini digunakan untuk mendefinisikan model dalam aplikasi Django yang mewakili tabel dalam basis data.

# %%
from django.db import models

class MyModel(models.Model):
    field1 = models.CharField(max_length=100)
    field2 = models.IntegerField()

# %% [markdown]
# django.contrib.auth.authenticate()
#
# Fungsi ini digunakan untuk mengautentikasi pengguna berdasarkan kredensial yang diberikan.

# %%
from django.contrib.auth import authenticate, login

def my_login_view(request):
    username = request.POST['username']
    password = request.POST['password']
    user = authenticate(request, username=username, password=password)
    if user is not None:
        login(request, user)
        return HttpResponse("Logged in successfully!")
    else:
        return HttpResponse("Invalid login credentials.")
